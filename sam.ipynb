# %%
pip install segment-geospatial
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import leafmap
from samgeo import tms_to_geotiff
from samgeo.text_sam import LangSAM

# %%
m = leafmap.Map(center=[28.131153137397405, 82.2983164525232], zoom=19, height="600px")
m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[28.131153137397405, 82.2983164525232], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = [-118.4932, 34.0404, -118.4903, 34.0417]

# %%
def tms_to_geotiff(output, bbox, zoom, source, overwrite):
    
    pass

# %%
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = [-118.4932, 34.0404, -118.4903, 34.0417]

# %%
image = "C:/Users/Modasir Abbasi/Desktop/full/data/nepal.tif"
bbox = [-118.4932, 34.0404, -118.4903, 34.0417]
tms_to_geotiff(output=image, bbox=bbox, zoom=19, source="Satellite", overwrite=True)

# %%
m.layers[-1].visible = False
m.add_raster(image, layer_name="Image")
m
# Out:
# Map(bottom=56172310.0, center=[28.131153137397405, 82.2983164525232], controls=(ZoomControl(options=['position…

# %%
from samgeo import SamGeo


sam = SamGeo(
    model_type="vit_h",
    sam_kwargs=None,
)

# %%
sam.generate(image, output="masks.tif", foreground=True, unique=True)

# %%
sam.show_masks(cmap="binary_r")

# %%
sam.show_anns(axis="off", alpha=1, output="annotations.tif")
